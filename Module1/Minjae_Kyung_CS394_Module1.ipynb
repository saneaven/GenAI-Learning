# %% [markdown]
# # CS394 Module 1

# %% [markdown]
# ### Load a pre-trained GPT-2 model

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load pre-trained GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2-medium")
model = GPT2LMHeadModel.from_pretrained("gpt2-medium")

# Set pad token
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
import random
import numpy as np
import torch

# Function to set seeds for reproducibility
def set_seed(seed_value=42):
    random.seed(seed_value)
    
    np.random.seed(seed_value)
    
    torch.manual_seed(seed_value)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed_value)

# %%
def autocomplete(prompt, max_length=50, temperature=0.7, top_k=50, top_p=0.9, do_sample=True):
    # Encode the prompt with attention mask
    inputs = tokenizer(prompt, return_tensors="pt")

    if not do_sample:
        temperature = None
        top_k = None
        top_p = None
    
    # Generate continuation
    with torch.no_grad():
        output = model.generate(
            inputs['input_ids'],
            attention_mask=inputs['attention_mask'],
            max_length=max_length,
            temperature=temperature,
            top_k=top_k,
            top_p=top_p,
            do_sample=do_sample,
            pad_token_id=tokenizer.eos_token_id
        )
    
    # Decode and return the generated text
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# %%
set_seed(42)

# %% [markdown]
# ### Create 3 different story starters in different genres/styles.

# %%
prompts = [
    "When you leave because you are weary of me, I shall let you go gently, without a word.",
    "The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.",
    "In an era where the need for machines to become human had vanished, a man was standing on a cliff."
]

for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
# Out:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. And you shall not return to me till you have taken your rest. I will make you a covenant with your heart. And I will give you my heart. And I will give you my heart. And you shall be mine and my soul. And I will give you my heart. And I will give you my heart. And I will give you my heart. And I will give you my
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# The train reached the end of the tunnel and the snow was falling heavily, and the train began to slow down.
#
# "Ahh, that's it. We should be heading out of here now."
#
# The black-haired girl with white hair on her head said.
#
# As the train passed by, the girl took out a knife from her bag and placed
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# He was surrounded by a crowd of people.
#
# They had all gathered to listen to his talk.
#
# "The reason I am here is because I want to help you. I want to teach you how to be a man. I want to teach you how to be a man."
#
# At that moment, a voice called out to him.
#
# "Master
# --------------------------------------------------

# %% [markdown]
# ### Then adjust for

# %% [markdown]
# #### Greedy decoding vs. sampling

# %%
print("Greedy Decoding Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, do_sample=False)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
print("=" * 50)
print("-" * 50)
print("Sampling Decoding Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, do_sample=True)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
# Out:
# Greedy Decoding Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. But if you leave because you are weary of me, I shall let you go with a shout, without a word. But if you leave because you are weary of me, I shall let you go with a shout, without a word. But if you leave because you are weary of me, I shall let you go with a shout, without a word. But if you leave because you are
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a
# --------------------------------------------------
# ==================================================
# --------------------------------------------------
# Sampling Decoding Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. But you will be wise, and I will tell you all my plans for the future." Then I went out and told my brother that I had seen a young woman, and I said to her, "Go and see that she is not a woman of evil." So she went and saw her, and she was a beautiful woman. She was a woman of good character, and she told me
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country. The train started to move again, and as it did so, the snow began to fall.
#
# As the train passed the train station, it suddenly came to a stop. It stopped and looked around, and then it turned around and went back to the train station.
#
# "I'm here, you idiot."
#
# The train was very quiet, and the silence was so
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# "I think I'll go with this."
#
# "I think it's too early to give up on it."
#
# "But I'm not sure if I'll be able to find a suitable place to sleep."
#
# "That's not the point."
#
# The man, named Kiyotaka Koyama, was the former president of the Tokyo Metropolitan
# --------------------------------------------------

# %% [markdown]
# It looks like our friend heading to the snow country really wants to go home.

# %%
set_seed(42*42) # Change seed for different sampling results

# %%
print("Seed Changed for Different Sampling Results\n")
print("Greedy Decoding Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, do_sample=False)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
print("=" * 50)
print("-" * 50)
print("Sampling Decoding Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, do_sample=True)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
# Out:
# Seed Changed for Different Sampling Results
#
# Greedy Decoding Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. But if you leave because you are weary of me, I shall let you go with a shout, without a word. But if you leave because you are weary of me, I shall let you go with a shout, without a word. But if you leave because you are weary of me, I shall let you go with a shout, without a word. But if you leave because you are
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# "I'm going to go home now."
#
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a world where machines were the norm. He was a man who had been born into a
# --------------------------------------------------
# ==================================================
# --------------------------------------------------
# Sampling Decoding Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. I have been expecting you, and have given you a little time to rest. You will not come here again until you are satisfied."
#
# "I will not come here again."
#
# "I do not care, I will come again."
#
# "But I will not."
#
# "I will not."
#
# "I will not."
#
# "I will not."
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country. The train stopped at the foot of a massive cliff. The train's driver looked up at the dark and dark sky. The train's passengers had to wait for hours for the train to reach the town. The train was packed with snow and ice. The train was traveling at an incredible speed.
#
# "We have arrived at the city."
#
# "Ah, so you're here
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. He had the ability to change himself into a machine, but it would take a while to become a machine.
#
# He had the power to change himself into a machine.
#
# The man had the ability to change himself into a machine.
#
# He had the power to change himself into a machine.
#
# He had the power to change himself into a machine.
#
# He
# --------------------------------------------------

# %% [markdown]
# The model utilizing the greedy method to output results without sampling consistently wants to go home even if the seed changes, but the model using sampling is producing different results since the seed changes.

# %% [markdown]
# #### Different temperature values

# %%
set_seed(42) # Reset seed back to original

print("Low Temperature Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, temperature=0.1)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
print("=" * 50)
print("-" * 50)
print("High Temperature Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, temperature=2.0) # Let's burn it all down
    print(f"[Output]")
    print(completion)
    print("-" * 50)
# Out:
# Low Temperature Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. I shall let you go gently, without a word. I shall let you go gently, without a word. I shall let you go gently, without a word. I shall let you go gently, without a word. I shall let you go gently, without a word. I shall let you go gently, without a word. I shall let you go gently, without a word. I shall
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# "I'm sorry, but I can't go on."
#
# "I'm sorry, but I can't go on."
#
# "I'm sorry, but I can't go on."
#
# "I'm sorry, but I can't go on."
#
# "I'm sorry, but I can't go on."
#
# "I'm sorry, but
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. He was a man who had been born into a world where machines were the norm, and he was a man who had been born into a world where machines were the enemy.
#
# "I'm sorry, I'm sorry."
#
# "I'm sorry."
#
# "I'm sorry."
#
# "I'm sorry."
#
# "I'm sorry."
#
# "I
# --------------------------------------------------
# ==================================================
# --------------------------------------------------
# High Temperature Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. My dear Lord do your will.' I thanked Heaven with tears in his ears. 'You understand not those things only!' he repeated in perfect joy. I thought, perhaps he would let some sort of farewell to him, just out of love and interest to that young one whose little heart it was, when not of his own doing? When the last rays of heaven shone the first-made love
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country. There seemed no less danger.
#
# One of many cars sat waiting next to its own open entrance and only about the diameter of half-a-million people were within an eight-second lead. They waved their signs for a long time – the ones bearing the phrase "Vera," "Rosenhilde, Gud," was my favorite! It sounded more confident than usual –
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. From the ledge stood nine knights, ten guardsmen as well as several archers that was mounted like a monster. The four in front formed a solid shape.
#
# In her right shoulder guard as she wore another magic armors that gave off an evil aura and with it also protected from magecraft skills – in addition from her heavy helmet as it would cover her torso that showed no sign
# --------------------------------------------------

# %% [markdown]
# The low-temperature friend is really good at apologizing. You really should apologize after cooling off your head. The high-temperature friend is so hot that I feel like my brain is going to melt.

# %%
set_seed(42*42) # Reset seed back to original

print("Low Temperature Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, temperature=0.1)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
print("=" * 50)
print("-" * 50)
print("High Temperature Results:")
for prompt in prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100, temperature=2.0) # Let's burn it all down
    print(f"[Output]")
    print(completion)
    print("-" * 50)
# Out:
# Low Temperature Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. I shall not be angry with you, but I shall be kind to you. I shall not be angry with you, but I shall be kind to you. I shall not be angry with you, but I shall be kind to you. I shall not be angry with you, but I shall be kind to you. I shall not be angry with you, but I shall be kind to you
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# "I'm going to go home now," said the girl.
#
# "I'm going to go home now," said the boy.
#
# "I'm going to go home now," said the girl.
#
# "I'm going to go home now," said the boy.
#
# "I'm going to go home now," said the girl.
#
# "
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. He was wearing a white robe, and he was holding a sword.
#
# "I'm going to kill you."
#
# "I'm going to kill you."
#
# "I'm going to kill you."
#
# "I'm going to kill you."
#
# "I'm going to kill you."
#
# "I'm going to kill you."
#
# "I
# --------------------------------------------------
# ==================================================
# --------------------------------------------------
# High Temperature Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. My words are yours alone.' The young gentleman gave three small clits of pleasure in a low voice which was distinctly not amused, just in case all that was required of them and his whole nature at this juncture were just as they'd long ago come, into this strange predicament." The old men made noise, one in the air and each in silence. Mr. Henry glanced about, trying
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country. It began crawling up into mountains where the snow is thick and there was no way the wind could blow them back as fast and straight as they were traveling. The road came off course towards where the mountain peak's edge, I assume towards his cave like mouth where one should stand if you go up or down some great mountain to the west or for a day at a time from the western direction
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. It was a world beyond even human experience: an entire plane above human activity — but all forlorn for his existence's use to his benefit, an invisible being standing atop the horizon to gaze into the future. A lonely tower in the sky in darkness: but perhaps something had appeared above, hidden at the base beneath his feet: one where the unknown could shine far into life to see
# --------------------------------------------------

# %% [markdown]
# I can't die like this

# %% [markdown]
# #### How the opening sentence shapes the continuation

# %%
set_seed(42*42) # Reset seed back to original

# %%
short_prompts = [
    "When you leave because",
    "The train passed",
    "In an era"
]
long_prompts = prompts

# %%
print("Short Prompt Results:")
for prompt in short_prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
print("=" * 50)
print("-" * 50)
print("Long Prompt Results:")
for prompt in long_prompts:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=100)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
# Out:
# Short Prompt Results:
# --------------------------------------------------
#
# Prompt: When you leave because
#
# [Output]
# When you leave because of the strike, you're not going to get paid," he said. "You're not going to be able to afford a meal or anything."
#
# "It's going to be very difficult for them to make ends meet," he said.
#
# He said some of the workers are still working without pay.
#
# "They're going to have to take whatever they can," he said.
#
# The workers say the administration failed to provide them with adequate notice of
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed
#
# [Output]
# The train passed by the apartment building where the victims were killed, and a police car was seen in the area, according to police.
#
# Police have not released any details about the alleged suspects, but said they had been interviewed by the FBI.
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era
#
# [Output]
# In an era where the top-ranked team in the country is still searching for its way back into the top 10, Oregon is no longer the only team in the country that is struggling to find its groove.
#
# It's time for the Ducks to come out of the shadows and show what they can do when they play against a team that is ranked in the top 15.
#
# The Ducks will be looking for their second win in three games on Saturday.
#
# This is a team that
# --------------------------------------------------
# ==================================================
# --------------------------------------------------
# Long Prompt Results:
# --------------------------------------------------
#
# Prompt: When you leave because you are weary of me, I shall let you go gently, without a word.
#
# [Output]
# When you leave because you are weary of me, I shall let you go gently, without a word. For my love is not to be pained, nor is it to be annoyed, but to be rejoiced."
#
# And she said to him, "Heaven has given you an opportunity, and you have taken it. For if you do not let me go, I shall not find rest in the land of my inheritance, for it is not mine. If you have an opportunity,
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# [Output]
# The train passed through the endless tunnel, and when it finally saw the light, it was the snow country.
#
# The first thing I noticed was the light was gone. It was only after I looked around that I noticed the train was gone. I was surprised. It must have been in the snow for a while.
#
# I ran out of the train. The train was gone.
#
# I ran up the steps of the train and jumped in the snow. I was frozen in place
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: In an era where the need for machines to become human had vanished, a man was standing on a cliff.
#
# [Output]
# In an era where the need for machines to become human had vanished, a man was standing on a cliff. He had no arms, legs or eyes. His body was covered in a black cloak.
#
# A white man appeared.
#
# "This is… Is this guy really human?"
#
# "Yes."
#
# The white man said in a low voice.
#
# "He's alive!"
#
# The man who appeared was a female.
#
# She had long black hair and
# --------------------------------------------------

# %% [markdown]
# Oregon mentioned

# %% [markdown]
# #### English and Korean (Just for fun)

# %%
korean_prompt = [
    "나보기가 역겨워 가실 때에는 말 없이 고이보내 드리오리다",
    "기차가 끝없는 터널을 지나 마침내 빛을 보니, 설국이였다.",
    "기계가 인간이 될필요가 없어져 버린 시대에 한 남자가 절벽위에 서있었다."
] # Basically the same prompts but in Korean

# %%
print("Korean Prompt Results:")
for prompt in korean_prompt:
    print("-" * 50)
    print(f"\nPrompt: {prompt} \n")
    completion = autocomplete(prompt, max_length=200)
    print(f"[Output]")
    print(completion)
    print("-" * 50)
# Out:
# Korean Prompt Results:
# --------------------------------------------------
#
# Prompt: 나보기가 역겨워 가실 때에는 말 없이 고이보내 드리오리다
#
# [Output]
# 나보기가 역겨워 가실 때에는 말 없이 고이보내 드리오리다.
#
# 행리오리다: 유정리에 반 정았이 드리오리다.
#
# 행리오리다: 유정리에 반 정았이 드리오리다.
#
# 아명이 정았 �
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: 기차가 끝없는 터널을 지나 마침내 빛을 보니, 설국이였다.
#
# [Output]
# 기차가 끝없는 터널을 지나 마침내 빛을 보니, 설국이였다.
#
# 기차가 지나 마침내 보니 내지말 마침내 빛을 보니, 보니 설국이였다. 설국이였다.
#
# 포마 말사 지나 지나도 내도 설도
# --------------------------------------------------
# --------------------------------------------------
#
# Prompt: 기계가 인간이 될필요가 없어져 버린 시대에 한 남자가 절벽위에 서있었다.
#
# [Output]
# 기계가 인간이 될필요가 없어져 버린 시대에 한 남자가 절벽위에 서있었다. 아만 것성기 사람지기에 시대에 있었어져 서있가 없어져 버린 시대에 한 남자가 절벽위에 서�
# --------------------------------------------------

# %% [markdown]
# Basically it says:
# - Yeglas half fredis give willingly
# - fourma horsebuy pass pass but I too snow too
# - Aman it[cansored] personlosed era being standwasga meaningless

# %% [markdown]
# Yes they are just meaningless trashes

# %% [markdown]
# ## Observations

# %% [markdown]
# First, while the greedy approach, which selects only the highest probabilities, appeared to produce coherent sentences, it felt lacking in creativity as I couldn't obtain different results even when trying different seeds. On the other hand, the sampling method had some oddities (although the whole thing was strange, such as grammatically incorrect parts), but its creativity stood out as it produced diverse results when the seeds were changed.
#
# Also, when I lowered the temperature during sampling, it produced coherent sentences similar to the greedy approach. At this point, unlike the greedy method, changing the seed did yield different content, but I received the impression that the structure was similar. When I raised the temperature extremely high, although it resulted in a list of "brainrot" words, I was still able to confirm that the content changed significantly depending on the seed.
#
# Furthermore, when I removed the preceding content in the prompt, naturally, I could see the sentences heading in a different direction compared to the original, relatively longer prompt. I was also able to confirm that it could not perform inference on Korean prompts at all, likely because it wouldn't have been trained on languages like Korean during the GPT-2 era.
