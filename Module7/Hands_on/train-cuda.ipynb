# %% [markdown]
# # Supervised Fine-Tuning on CUDA
#
# <a target="_blank" href="https://colab.research.google.com/github/simonguest/CS-394/blob/main/src/07/notebooks/train-cuda.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
# <a target="_blank" href="https://github.com/simonguest/CS-394/raw/refs/heads/main/src/07/notebooks/train-cuda.ipynb">
#   <img src="https://img.shields.io/badge/Download_.ipynb-blue" alt="Download .ipynb"/>
# </a>

# %% [markdown]
# ## Dependencies

# %%
# !uv pip install -q datasets bitsandbytes trl

# %% [markdown]
# ## Model parameters

# %%
import os

DATASET_REPO = "saneaven/novel-dataset-v0" # Change this to your uploaded dataset location on HF

BASE_MODEL_VENDOR = "Qwen" # Change this to your desired base model
BASE_MODEL_NAME = "Qwen3-1.7B" # Change this to your desired base model
BASE_MODEL = f"{BASE_MODEL_VENDOR}/{BASE_MODEL_NAME}"

PROJECT_NAME = "novel-agent" # Name of your training project
os.environ["WANDB_PROJECT"] = PROJECT_NAME # WandB will use the same project name

MODEL_NAME = f"{BASE_MODEL_NAME}-{PROJECT_NAME}" # Final model name
HF_USERNAME = "saneaven" # Hugging Face username - used to upload your final models

MODEL_FOLDER = f"./models/{MODEL_NAME}" # Local folder for storing the model files during training

# %% [markdown]
# ## Training hyperparameters

# %%
BATCH_SIZE = 4
GRADIENT_ACCUMULATION_STEPS = 4
LEARNING_RATE = 2e-4
NUM_EPOCHS = 3
MAX_SEQ_LENGTH = 512

# LoRA-specific Parameters
LORA_R = 16
LORA_ALPHA = 32
LORA_DROPOUT = 0.05

# Use 4-bit quantization for efficiency (QLoRA)
USE_4BIT = True

# %% [markdown]
# ## API keys and tokens

# %%
import sys
import os
from dotenv import load_dotenv

if 'google.colab' in sys.modules:
  from google.colab import userdata # type:ignore
  os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')
  os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')
  print("HF and WANDB API Tokens set for Colab")
else:
  load_dotenv()
  print("Loaded env vars from .env")
# Out:
# HF and WANDB API Tokens set for Colab

# %% [markdown]
# ## Load dataset from Hugging Face

# %%
from datasets import load_dataset
dataset = load_dataset(DATASET_REPO)
# Out:
# README.md:   0%|          | 0.00/868 [00:00<?, ?B/s]
# data/train-00000-of-00006.parquet:   0%|          | 0.00/438M [00:00<?, ?B/s]
# data/train-00001-of-00006.parquet:   0%|          | 0.00/445M [00:00<?, ?B/s]
# data/train-00002-of-00006.parquet:   0%|          | 0.00/457M [00:00<?, ?B/s]
# data/train-00003-of-00006.parquet:   0%|          | 0.00/449M [00:00<?, ?B/s]
# data/train-00004-of-00006.parquet:   0%|          | 0.00/435M [00:00<?, ?B/s]
# data/train-00005-of-00006.parquet:   0%|          | 0.00/434M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/299M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/320k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/106635 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11848 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/13 [00:00<?, ? examples/s]

# %% [markdown]
# ## Format dataset for correct chat template

# %%
from transformers import AutoTokenizer

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

def format_chat_template(example):
    messages = example["messages"]
    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=False
    )
    return {"text": text}

formatted_dataset = dataset.map(
    format_chat_template,
    remove_columns=dataset['train'].column_names # type: ignore
)

print("\nFormatted example:")
print(formatted_dataset['train'][0]['text'][:500])  # type: ignore
# Out:
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Map:   0%|          | 0/106635 [00:00<?, ? examples/s]
# Map:   0%|          | 0/11848 [00:00<?, ? examples/s]
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Formatted example:
# <|im_start|>system
#
#
# You are an expert novel-writing assistant. You collaborate with authors to build compelling stories using structured project tools. You have access to tools for creating and managing characters, locations, organizations, lore entries, outlines, and manuscript text. Always use the appropriate tool calls to read existing project state before making changes, and to persist your work.
#
# ## Current Project
# - **Title**: Summerfield: A Tale of Rural Life
# - **Genre**: Domestic Fictio

# %% [markdown]
# ## Load base model with QLoRA configuration

# %%
import torch
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

# Configure 4-bit quantization
if USE_4BIT:
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16,
        bnb_4bit_use_double_quant=True,
    )
else:
    bnb_config = None

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=bnb_config,
    device_map="auto",
    trust_remote_code=True,
    dtype=torch.bfloat16,
)

# Prepare model for k-bit training
if USE_4BIT:
    model = prepare_model_for_kbit_training(model)

# Configure LoRA
peft_config = LoraConfig(
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                    "gate_proj", "up_proj", "down_proj"],
    bias="none",
    task_type="CAUSAL_LM",
)

# Apply LoRA
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()
# Out:
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# trainable params: 17,432,576 || all params: 2,049,172,480 || trainable%: 0.8507

# %% [markdown]
# ## Create training configuration and trainer

# %%
import os
from transformers import TrainingArguments
from trl import SFTTrainer

report_to = "none"
if os.environ.get("WANDB_API_KEY") != None:
  report_to = "wandb"

# Training arguments
training_args = TrainingArguments(
    output_dir=MODEL_FOLDER,
    num_train_epochs=NUM_EPOCHS,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type="cosine",
    warmup_ratio=0.1,
    logging_steps=10,
    eval_strategy="steps",
    eval_steps=1000,
    save_strategy="steps",
    save_steps=1000,
    save_total_limit=2,
    bf16=True,
    gradient_checkpointing=True,
    optim="paged_adamw_8bit",
    report_to=report_to,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
)

# Create trainer
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=formatted_dataset["train"],
    eval_dataset=formatted_dataset["validation"],
    processing_class=tokenizer,
)

# Save the tokenizer model as this won't change during training
tokenizer.save_pretrained(f"{MODEL_FOLDER}/lora")
# Out:
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Adding EOS to train dataset:   0%|          | 0/106635 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/106635 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (194568 > 131072). Running this sequence through the model will result in indexing errors
# Truncating train dataset:   0%|          | 0/106635 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/11848 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/11848 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/11848 [00:00<?, ? examples/s]
# ('./models/Qwen3-1.7B-novel-agent/lora/tokenizer_config.json',
#  './models/Qwen3-1.7B-novel-agent/lora/chat_template.jinja',
#  './models/Qwen3-1.7B-novel-agent/lora/tokenizer.json')

# %% [markdown]
# ## Train and save the final model

# %%
# Start training
trainer.train()

# Save the final model
trainer.save_model(f"{MODEL_FOLDER}/lora")
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151645}.
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: saneaven (saneaven-digipen) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/wandb/run-20260228_064727-dhe15jrl</code>
# Syncing run <strong><a href='https://wandb.ai/saneaven-digipen/novel-agent/runs/dhe15jrl' target="_blank">stellar-firebrand-2</a></strong> to <a href='https://wandb.ai/saneaven-digipen/novel-agent' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/saneaven-digipen/novel-agent' target="_blank">https://wandb.ai/saneaven-digipen/novel-agent</a>
#  View run at <a href='https://wandb.ai/saneaven-digipen/novel-agent/runs/dhe15jrl' target="_blank">https://wandb.ai/saneaven-digipen/novel-agent/runs/dhe15jrl</a>
#     <div>
#
#       <progress value='11414' max='19995' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11414/19995 7:52:52 < 5:55:33, 0.40 it/s, Epoch 1.71/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>1.709685</td>
#       <td>1.682264</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.588150</td>
#       <td>0.603558</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.332461</td>
#       <td>0.285360</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.239122</td>
#       <td>0.210930</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.180330</td>
#       <td>0.200918</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.189552</td>
#       <td>0.191131</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.191694</td>
#       <td>0.185137</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.176281</td>
#       <td>0.181137</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.193911</td>
#       <td>0.177910</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.202808</td>
#       <td>0.175713</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.168177</td>
#       <td>0.173193</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='19995' max='19995' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [19995/19995 13:46:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>1.709685</td>
#       <td>1.682264</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.588150</td>
#       <td>0.603558</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.332461</td>
#       <td>0.285360</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.239122</td>
#       <td>0.210930</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.180330</td>
#       <td>0.200918</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.189552</td>
#       <td>0.191131</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.191694</td>
#       <td>0.185137</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.176281</td>
#       <td>0.181137</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.193911</td>
#       <td>0.177910</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.202808</td>
#       <td>0.175713</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.168177</td>
#       <td>0.173193</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.190687</td>
#       <td>0.171675</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.152292</td>
#       <td>0.170218</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.171610</td>
#       <td>0.169440</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.128526</td>
#       <td>0.168859</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.130685</td>
#       <td>0.168498</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.169543</td>
#       <td>0.168291</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.182803</td>
#       <td>0.168245</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.156421</td>
#       <td>0.168244</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ## Load the final model

# %%
from transformers import pipeline

PROJECT_NAME = "novel-agent"

pipe = pipeline(
    "text-generation",
    model=f"{MODEL_FOLDER}/lora",
    tokenizer=f"{MODEL_FOLDER}/lora",
    temperature = 0.7,
    max_new_tokens = 256,
)
# Out:
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Loading weights:   0%|          | 0/392 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.

# %% [markdown]
# ## Test the final model using the test dataset

# %%
import random

idx = random.randint(0, len(formatted_dataset['test']) -1)
test_data = formatted_dataset['test'][idx]["text"]

output = pipe(test_data)
print(output[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# <|im_start|>system
#
#
# You are an expert novel-writing assistant. You collaborate with authors to build compelling stories using structured project tools. You have access to tools for creating and managing characters, locations, organizations, lore entries, outlines, and manuscript text. Always use the appropriate tool calls to read existing project state before making changes, and to persist your work.
#
# ## Current Project
# - **Title**: Full structural outline of the pamphlet
# - **Genre**: True crime, Sensationalism, 19th-century social melodrama
# - **Logline**: When a respectable mother discovers her daughter’s drowning and a last note blaming a mysterious woman, she and her daughter’s betrothed hunt a mobile procuress across American cities — capturing Almira Cathcart, who confesses in writing and kills herself with prussic acid, leaving behind a horrifying catalogue of ruined girls and motives of revenge.
#
#
#
# ## Characters
#
# - **Almira Cathcart**: The central antagonist: a polished, itinerant procuress who lures, sells and ruins young women; intelligent, literary in expression, remorseless in practice, ultimately suicidal.
#
#
# - **Mrs. (Julia's) Clark (narrator of pursuit sections)**: The heartbroken mother and principal pursuer; narrator of the pursuit sections and initial framing voice who organizes the search for Almira.
#
#
# - **Julia Clark**: The victim whose suicide sets the plot in motion: a virtuous, beloved daughter who succumbs to shame and despair after being led into ruin.
#
#
# - **T. Passmore Hughs (Mr. Hughs / Thadeus)**: Julia's betrothed and the pragmatic, determined male pursuer who coordinates the investigation and helps secure Almira's capture; also reads the confession aloud.
#
#
# - **Mrs. Krider**: A bereaved mother who has been victimized by Almira (child stolen/ruined); becomes a determined ally in tracking Almira and recovering her daughter.
#
#
# - **Agnes (Mrs.) Krider**: Referenced in Almira's confession as Almira's object of vengeance (Edward Krider married Agnes), the original social rival whose family Almira targeted.
#
#
# - **Madam Adair**: Head of an establishment (brothel/boarding house) where kidnapped children (including Katie) and ruined girls are placed; practical and mercenary.
#
#
# - **Annie (the colored girl / servant)**: A young Black woman in Almira's employ who runs errands, collects mail, and serves as a gatekeeper in Philadelphia; lies when pressured but is part of Almira's operations.
#
#
# - **Keeper of the Morgue**: A practical municipal official who aids identification and handles bodies with professional coolness.
#
#
# - **Ella Winters**: One of Almira's early victims: a young, naive girl from a modest family whom Almira manipulates and sells for money; commits suicide.
#
#
# - **Bertha Holstein**: German orphan taken by Almira, groomed and sold; proud and spirited, later becomes violent and descends into alcoholism and degradation.
#
#
# - **Olivia (unnamed surname in text)**: A clergyman's daughter in Philadelphia who is lured by Almira to the theatre and then corrupted and sold.
#
#
# - **Charlotte Clifford**: A girl from Baltimore who becomes one of Almira's victims; her uncle leads a furious pursuit.
#
#
# - **Leonie Prangler**: A Creole flower-seller in New Orleans who is groomed, marketed to planters and eventually taken to Havana where she dies under violent circumstances.
#
#
# - **Major James Welling**: A dashing, married U.S. Army officer who briefly associates with Almira during her early years of socializing; an early libertine contact in her narrative.
#
#
# - **Edward Krider**: The man Almira loved, married Agnes Krider and spurned Almira; catalyst for Almira's vow of vengeance.
#
#
# - **Mr. S****, Mr. Dexter, Mr. Jones and unnamed gentleman patrons**: Composite of the wealthy male clients, officials and politicians who pay Almira for access to girls or to have her arrange liaisons.
#
#
# - **Policeman / Detective (unnamed)**: Law enforcement actors who assist in the arrest of Almira and comment on the moral horror of her deeds.
#
#
#
#
#
# ## Locations
#
# - **Mrs. Clark's home (New York)**: Family residence where Julia and her mother lived; the locus of intimacy and the scene of the farewell before Julia's disappearance.
#
#
# - **The Morgue (City Morgue)**: Municipal place for the reception and identification of drowned and unknown bodies; where Julia's body is identified and where the keeper plays a procedural role.
#
#
# - **Green Street house (various Green Streets)**: The misleading address on Julia's note leads to confusion over multiple Green Streets; Almira's previous New York lodging was in a building on one such Green Street.
#
#
# - **Philadelphia Pine Street lodging**: A Philadelphia boarding house where Almira had letters forwarded and where a colored girl (Annie) acted as letter proxy.
#
#
# - **Railroad depots and intercity routes (Pittsburgh, Cincinnati, New Orleans, Memphis, Chicago, Cincinnati)**: Transit infrastructure that forms the chase-line—Almira moves between cities, and pursuers use railroads and detectives to follow her trail.
#
#
# - **Cincinnati lodging (Almira's last retreat)**: The city and the specific house where Almira takes refuge and is finally located, arrested and where she commits suicide.
#
#
# - **Madam Adair's establishment (New York brothel)**: A grand-looking house run by Madam Adair where stolen or boarded girls (including Katie) are placed for training and sale.
#
#
# - **Central Park (rustic bench)**: Where Almira first meets Julia and begins to court her attention; a public but intimate place for predation.
#
#
# - **Various American cities referenced (Washington, Philadelphia, Baltimore, New Orleans, Chicago, Memphis)**: Regional settings that reveal the national sweep of Almira's operations and the mobility of both criminal entrepreneurs and their patrons.
#
#
#
#
#
# ## Organizations
#
# - **Almira Cathcart's procuring network**: An informal criminal-commercial network that finds, grooms, markets and places young women with wealthy men and brothels across cities.
#
#
# - **Madam Adair's house (institutional brothel)**: An organized establishment that receives boarded girls, operates as a commercial brothel, and acts as endpoint for some of Almira's placements.
#
#
#
#
#
#
#
#
# The user is in the world-building phase, creating story elements for their novel.
# <|im_end|>
# <|im_start|>user
# Let's add Municipal law enforcement (police, coroner, morgue keeper) as a faction/organization. Public institutions tasked with identification, arrest and legal order; operate procedurally but require citizen tips to locate Almira.<|im_end|>
# <|im_start|>assistant
# <tool_call>
# {"name": "create_story_object", "arguments": {"content": "Values: Enforcement of law, public order, municipal duty. Origins: City municipal institutions (police force, coroner, morgue). Members: Policemen who serve warrants, coroner\u0027s clerks, morgue keeper. Relationships: Responsive to citizen initiatives (Mrs. Clark and Mr. Hughs), limited by jurisdictional mobility of the fugitive. Current goals: Make arrests when probable cause is presented; handle bodies and evidence respectfully and lawfully.", "description": "Public institutions tasked with identification, arrest and legal order; operate procedurally but require citizen tips to locate Almira.", "name": "Municipal law enforcement (police, coroner, morgue keeper)", "type": "organization"}}
# </tool_call><|im_end|>
# <|im_start|>user
# <tool_response>
# {"success": true, "id": "c763db3acd6645098a4768f6f5b2ed93"}
# </tool_response><|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# Done! I've created **Municipal law enforcement (police, coroner, morgue keeper)** and added them to the project. This enriches the setting nicely.<|im_end|>

# %% [markdown]
# ## Create a model card

# %%
from huggingface_hub import ModelCard

card_content = f"""---
base_model: {BASE_MODEL}
tags:
- peft
- lora
- text-generation
---

# {MODEL_NAME}

## Model Description
Fine-tuned from `{BASE_MODEL}` using QLoRA (4-bit) with supervised fine-tuning.

## Training Details
- Dataset: `{DATASET_REPO}`
- LoRA rank: {LORA_R}, alpha: {LORA_ALPHA}
- Epochs: {NUM_EPOCHS}, Learning rate: {LEARNING_RATE}

## Intended Use

This model is a test model used for the CS-394/594 class at DigiPen.

The model is designed to provide a summary explanation of a snippet of Python code, to be used in an IDE. This model takes a snippet of code (passed as the user prompt) and returns a two paragraph explanation of what the code does, including an analogy that helps students better understand how the code functions.

## Limitations

This model is a single-turn model and has not been trained on support long, multi-turn conversations.
"""

card = ModelCard(card_content)
card.save(f"{MODEL_FOLDER}/lora/README.md")

# %% [markdown]
# ## Merge the models

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

from peft import PeftModel

# Load the configuration and model
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    device_map="auto",
    dtype=torch.bfloat16,
)
adapter_model = PeftModel.from_pretrained(base_model, f"{MODEL_FOLDER}/lora")

# Merge and save the model
merged_model = adapter_model.merge_and_unload() # type: ignore
merged_model.save_pretrained(f"{MODEL_FOLDER}/merged")
# Save the tokenizer
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
tokenizer.save_pretrained(f"{MODEL_FOLDER}/merged")

# Copy the model card to the merged folder
# !cp {MODEL_FOLDER}/lora/README.md {MODEL_FOLDER}/merged/.
# Out:
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Upload the merged model and adapter to Hugging Face

# %%
from huggingface_hub import HfApi, create_repo

# Set the MODEL_REPO
MODEL_REPO = f"{HF_USERNAME}/{MODEL_NAME}"

# Initialize the API
api = HfApi()

# Create the repository (if it doesn't exist)
try:
    create_repo(MODEL_REPO, repo_type="model", exist_ok=True, private=False)
    print(f"Repository {MODEL_REPO} created or already exists")
except Exception as e:
    print(f"Error creating repo: {e}")

# Upload merged model files to root (this is the main model)
print("\nUploading merged model to root...")
api.upload_folder(
    folder_path=f"{MODEL_FOLDER}/merged",
    repo_id=MODEL_REPO,
    repo_type="model",
    path_in_repo="",  # Empty string uploads to root
    commit_message="Upload merged model"
)

# Upload LoRA adapter to subfolder (optional but useful for reference)
print("\nUploading LoRA adapter...")
api.upload_folder(
    folder_path=f"{MODEL_FOLDER}/lora",
    repo_id=MODEL_REPO,
    repo_type="model",
    path_in_repo="lora_adapter",  # Keep adapter in subfolder
    commit_message="Upload LoRA adapter"
)

print(f"\n✓ All files uploaded successfully to https://huggingface.co/{MODEL_REPO}")
# Out:
# Repository saneaven/Qwen3-1.7B-novel-agent created or already exists
#
# Uploading merged model to root...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...ent/merged/tokenizer.json:   0%|          | 28.3kB / 11.4MB
#   .../merged/model.safetensors:   0%|          | 29.6kB / 4.06GB
# Uploading LoRA adapter...
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...agent/lora/tokenizer.json: 100%|##########| 11.4MB / 11.4MB
#   ...adapter_model.safetensors:   0%|          | 45.8kB / 69.8MB
#   ...nt/lora/training_args.bin:  90%|########9 | 5.08kB / 5.65kB
# ✓ All files uploaded successfully to https://huggingface.co/saneaven/Qwen3-1.7B-novel-agent
